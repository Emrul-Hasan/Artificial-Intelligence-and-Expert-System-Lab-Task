# %% [markdown]
# Name : MD EMRUL HASAN EMON
# ID : 19-40357-1
# LAB WEEK 1

# %%
a= 350
b= 11
c = a+ b;
print(c)

# %%
a*5

# %%
import math
math.pi

# %%
math.sqrt(100)

# %%
math.e

# %%
math.sin(45)

# %%
S = "EMRUL"
len(S)

# %%
S[4]

# %%
S[-1]

# %%
S[0:2]

# %%
S[1:]

# %%
S[:2]

# %%
S[:]

# %%
S+"hasan"

# %%
S*2

# %%
S+"2"

# %%
S.find('MR')

# %%
S

# %%
S.islower()

# %%
S.isalpha()

# %%
dir(S)

# %%
name  = "Arif Hossain Mia"
name

# %%
name.split(' ')

# %%
fn = name.split(' ')[0]
print(fn)

# %%
ln = name.split(' ')[-1]
print(ln)

# %%
import re
match = re.match('Hello[ \t]*(.*)world', 'Hello Python world')
match.group(1)

# %%
match = re.match('/(.*)/(.*)/(.*)', '/Emrul/Hasan/Emon')
match.groups( )

# %%
Z = ['mango', 'jackfruit', 'banana']
Z.sort( )
Z

# %%
Z.reverse()
Z

# %%
C = [5,'friut','jacks',22]
C

# %%
C[0] = 10
C

# %%
C+['apple',28]

# %%
C.pop(0)

# %% [markdown]
# NESTING

# %%
M = [['A','B','C'], ['D','E','F'], ['G','H','I']] 
M

# %%
M[1]

# %%
M[0][1]

# %% [markdown]
#  List Comprehensions

# %%
col = [row[0] for row in M] 
col

# %% [markdown]
# Nesting Revisited

# %%
rec = {'name': {'first': 'Emrul', 'last': 'Hasan'},
'age': 21.5}
rec['name']
rec['name']['last']

# %% [markdown]
# Sorting Keys: for Loops

# %%
Z = {'a': 1,'b': 2, 'c': 3}
Z

# %%
ks=Z.keys()
ks

# %%
Z

# %%
Z['e'] = 99
Z

# %%
for x in 'EMRUL':
 print (x.upper( ))

# %%
squares = [x ** 2 for x in [5, 10, 15, 20, 25]]
squares

# %%
squares = []
for x in [5, 10, 15, 20, 25]:
  squares.append(x ** 2)
squares

# %% [markdown]
# Tuples

# %%
T = (1, 2, 3, 4)
len(T)

# %%
T + (5, 6)
(1, 2, 3, 4, 5, 6)

# %%
X = set('Emrul')
Y = set(['E', 'M', 'O','N']) 
X, Y

# %%
X & Y

# %%
 X | Y

# %%
X-Y

# %%
import decimal
d = decimal.Decimal('2.30')
d + 1

# %%
1 > 2, 1 < 2

# %%
bool('Emrul')

# %%
L = ['Hasan'] * 5 
L

# %%
type(L)

# %%
if type(L) == list:
 print ('yes')

# %%
if type(L) == type([]):
 print ("yes")

# %%
if isinstance(L, list):
 print ('yes')

# %% [markdown]
# Class

# %%
f = open('data.txt', 'w') 
f.write('Hello\n') 
f.write('world\n')
f.close()
f = open('data.txt')
bytes = f.read() 
bytes
print(bytes)
bytes.split( )

# %%
A = ['Hasan','Emrul','Kamal','Rony','Nusrat','Rahim']
Sort = sorted(A)
print(Sort)

# %% [markdown]
# Function

# %%
def add(x,y):
   sum = x + y
   print(sum)
def sub(a,b):
    z = a-b
    print(z)
def a():
    print('No parameter passes')

    
add(10, 20)
add(200,30)
sub(110,10)
a()

# %%
def my_function():
   print("Emrul Hasan Emon")

def sem():
   print ('This is my 7th semester')
my_function()
sem()
